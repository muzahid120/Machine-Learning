# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv(r'C:\Users\SDS\Downloads\train.csv')
df=df.drop(columns=['PassengerId','Name','Ticket','Cabin'])
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 331       1    male  45.5      0      0   28.5000        S
# 733       2    male  23.0      0      0   13.0000        S
# 382       3    male  32.0      0      0    7.9250        S
# 704       3    male  26.0      1      0    7.8542        S
# 813       3  female   6.0      4      2   31.2750        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 106       3  female  21.0      0      0    7.6500        S
# 270       1    male   NaN      0      0   31.0000        S
# 860       3    male  41.0      2      0   14.1083        S
# 435       1  female  14.0      1      2  120.0000        S
# 102       1    male  21.0      0      1   77.2875        S
#
# [712 rows x 7 columns]

# %%
numeric_feature=[2,5]
catagorical_feature=[1,6]

# %%
num_transform=Pipeline(steps=[('imputer',SimpleImputer(strategy='median')),
('scaled',StandardScaler())])

# %%
cat_transform=Pipeline(steps=[('imputer',SimpleImputer(strategy='most_frequent')),
('onehot',OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessing=ColumnTransformer(transformers=[('num',num_transform,numeric_feature),
('cat',cat_transform,catagorical_feature)])

# %%
clf=Pipeline([('preprossor',preprocessing),
('model',LogisticRegression())])

# %%
from sklearn import set_config

set_config(display='diagram')
clf
# Out:
# Pipeline(steps=[('preprossor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaled',
#                                                                    StandardScaler())]),
#                                                   [2, 5]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %%
# Out:
# Pipeline(steps=[('preprossor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaled',
#                                                                    StandardScaler())]),
#                                                   [2, 5]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %%
param_grid = {
    'preprocessor__imputer__strategy': ['mean', 'median', 'most_frequent'],
    'model__C': [0.1, 1.0, 10.0],
    'model__solver': ['liblinear', 'lbfgs']
}

# %%
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='accuracy')

# %%
grid_search.fit(x_train, y_train)

# Print the best parameters
print(f"Best params:")
print(grid_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 grid_search.fit(x_train, y_train)
#       3 # Print the best parameters
#       4 print(f"Best params:")
#
# File c:\Users\SDS\.conda\envs\test2\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\SDS\.conda\envs\test2\lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
# ...
